# %%
import numpy as np
x = np.array([3, 4, 5])
y = np.array([4, 9, 7])

# %%
x.dtype
# Out:
# dtype('int32')

# %%
np.array([[1, 2], [3.0, 4]]).dtype
# Out:
# dtype('float64')

# %%
x = np.array([1, 2, 3, 4, 5, 6])
print('beginning x:\n', x)
x_reshape = x.reshape((2, 3))
print('reshaped x:\n', x_reshape)
# Out:
# beginning x:
#  [1 2 3 4 5 6]
# reshaped x:
#  [[1 2 3]
#  [4 5 6]]

# %%
print('x before we modify x_reshape:\n', x)
print('x_reshape before we modify x_reshape:\n', x_reshape)
x_reshape[0, 0] = 5
print('x_reshape after we modify its top left element:\n',
x_reshape)
print('x after we modify top left element of x_reshape:\n', x)
# Out:
# x before we modify x_reshape:
#  [1 2 3 4 5 6]
# x_reshape before we modify x_reshape:
#  [[1 2 3]
#  [4 5 6]]
# x_reshape after we modify its top left element:
#  [[5 2 3]
#  [4 5 6]]
# x after we modify top left element of x_reshape:
#  [5 2 3 4 5 6]

# %%
x = np.random.normal(size=50)
x
# Out:
# array([-1.00777152, -2.63880172,  0.48359248,  1.02574408, -0.87216271,
#         1.10427005,  0.39659606, -0.48919402, -1.54642617, -1.35171831,
#        -0.13533284,  2.2963494 ,  2.30907552,  1.95597402,  0.57907081,
#         0.42502663, -0.52922868,  2.43746909, -0.14999282, -1.82503981,
#         0.04136555,  2.37715197, -0.20375238,  0.70055503,  0.54519653,
#        -0.70302586,  1.4024109 ,  0.42950403,  0.49494399,  1.01743939,
#        -0.14212605, -1.12964155,  0.01522856, -2.00648508,  0.36296694,
#        -0.58666941,  0.05008418,  0.02139221, -0.11805628,  1.34321398,
#        -0.81555923,  0.40458826, -1.35134816,  0.47528292,  0.20179903,
#        -0.2582466 , -0.26833688,  0.90926184, -0.06406745, -1.41543655])

# %%
rng = np.random.default_rng(1303)
print(rng.normal(scale=5, size=2))
rng2 = np.random.default_rng(1303)
print(rng2.normal(scale=5, size=2))
# Out:
# [ 4.09482632 -1.07485605]
# [ 4.09482632 -1.07485605]

# %%
rng = np.random.default_rng(3)
y = rng.standard_normal(10)
np.mean(y), y.mean()
# Out:
# (-0.1126795190952861, -0.1126795190952861)

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize=(8, 8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.plot(x, y);

# %%
output = subplots(figsize=(8, 8))
fig = output[0]
ax = output[1]

# %%
fig, ax = subplots(figsize=(8, 8))
ax.plot(x, y, 'o');

# %%
fig, ax = subplots(figsize=(8, 8))
ax.scatter(x, y, marker='o');

# %%
fig, ax = subplots(figsize=(8, 8))
ax.scatter(x, y, marker='o')

# %%
fig, ax = plt.subplots(figsize=(8, 8))  # Assuming plt is matplotlib.pyplot
ax.set_title("Your Title Here")        # Call set_title() on ax
ax.scatter(x, y, marker='o')
ax.set_xlabel("this is the x-axis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(8, 8))  # Assuming plt is matplotlib.pyplot
#       2 ax.set_title("Your Title Here")        # Call set_title() on ax
#       3 ax.scatter(x, y, marker='o')
#
# NameError: name 'plt' is not defined

# %%
fig, axes = subplots(nrows=2,
ncols=3,
figsize=(15, 5))
